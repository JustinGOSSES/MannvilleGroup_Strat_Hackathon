# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import welly
welly.__version__
# Out:
# '0.3.0'

# %%
import os
env = %env

# %% [markdown]
# ## Load a well from LAS
#
# Use the `from_las()` method to load a well by passing a filename as a `str`.
#
# This is really just a wrapper for `lasio` but instantiates a `Header`, `Curve`s, etc.

# %%
well_path = 'SPE_006_originalData/OilSandsDB/Logs/'

# %%
from welly import Well

# %%
w = Well.from_las(well_path+'00-01-01-095-19W4-0.LAS')

# %%
w
# Out:
# <table><tr><th style="text-align:center;" colspan="2">PARMOUNT RES<br><small>00/01-01-095-19W4/0</small></th></tr><tr><td><strong>crs</strong></td><td>CRS({})</td></tr><tr><td><strong>tdd</strong></td><td>387.5</td></tr><tr><td><strong>location</strong></td><td>01-01-095-19W4</td></tr><tr><td><strong>td</strong></td><td>387.5</td></tr><tr><td><strong>data</strong></td><td>CALI, DPHI, GR, ILD, NPHI</td></tr></table>

# %%
tracks = ['CALI', 'GR', 'DPHI', 'NPHI', 'ILD']
w.plot(tracks=tracks)

# %%
r = Well.from_las(well_path+'00-01-04-075-23W4-0.LAS')
r
# Out:
# <table><tr><th style="text-align:center;" colspan="2">BOWTEX MARTEN HILLS 01-04<br><small>00/01-04-075-23W4/0</small></th></tr><tr><td><strong>crs</strong></td><td>CRS({})</td></tr><tr><td><strong>tdd</strong></td><td>640</td></tr><tr><td><strong>location</strong></td><td>00/01-04-075-23W4/0</td></tr><tr><td><strong>td</strong></td><td>640</td></tr><tr><td><strong>data</strong></td><td>CALI, DPHI, GR, ILD, NPHI</td></tr></table>

# %%
tracks = ['CALI', 'DPHI', 'GR', 'ILD', 'NPHI']
r.plot(tracks=tracks)

# %%
import lasio
l = lasio.read(well_path+"00-01-04-075-23W4-0.LAS")
l

# %%
l.curves
# Out:
# [CurveItem(mnemonic=DEPT, unit=M, value=00 001 00 00, descr=DEPTH        - DEPTH, original_mnemonic=DEPT, data.shape=(821,)),
#  CurveItem(mnemonic=ILD, unit=OHMM, value=00 120 00 00, descr=RESD         - DEEP RESISTIVITY (DIL), original_mnemonic=ILD, data.shape=(821,)),
#  CurveItem(mnemonic=NPHI, unit=V/V, value=00 330 00 00, descr=PHIN         - NEUTRON POROSITY (SANDSTONE), original_mnemonic=NPHI, data.shape=(821,)),
#  CurveItem(mnemonic=DPHI, unit=V/V, value=00 890 00 00, descr=PHID         - DENSITY POROSITY (SANDSTONE), original_mnemonic=DPHI, data.shape=(821,)),
#  CurveItem(mnemonic=GR, unit=API, value=00 310 00 00, descr=GR           - GAMMA RAY, original_mnemonic=GR, data.shape=(821,)),
#  CurveItem(mnemonic=CALI, unit=MM, value=00 280 01 00, descr=CAL          - CALIPER, original_mnemonic=CALI, data.shape=(821,))]

# %%
l.keys()
# Out:
# ['DEPT', 'ILD', 'NPHI', 'DPHI', 'GR', 'CALI']

# %%
l_depth = l['DEPT']
l_depth
# Out:
# array([ 435.  ,  435.25,  435.5 ,  435.75,  436.  ,  436.25,  436.5 ,
#         436.75,  437.  ,  437.25,  437.5 ,  437.75,  438.  ,  438.25,
#         438.5 ,  438.75,  439.  ,  439.25,  439.5 ,  439.75,  440.  ,
#         440.25,  440.5 ,  440.75,  441.  ,  441.25,  441.5 ,  441.75,
#         442.  ,  442.25,  442.5 ,  442.75,  443.  ,  443.25,  443.5 ,
#         443.75,  444.  ,  444.25,  444.5 ,  444.75,  445.  ,  445.25,
#         445.5 ,  445.75,  446.  ,  446.25,  446.5 ,  446.75,  447.  ,
#         589.  ,  589.25,  589.5 ,  589.75,  590.  ,  590.25,  590.5 ,
#         590.75,  591.  ,  591.25,  591.5 ,  591.75,  592.  ,  592.25,
#         592.5 ,  592.75,  593.  ,  593.25,  593.5 ,  593.75,  594.  ,
#         594.25,  594.5 ,  594.75,  595.  ,  595.25,  595.5 ,  595.75,
#         596.  ,  596.25,  596.5 ,  596.75,  597.  ,  597.25,  597.5 ,
#         597.75,  598.  ,  598.25,  598.5 ,  598.75,  599.  ,  599.25,
#         599.5 ,  599.75,  600.  ,  600.25,  600.5 ,  600.75,  601.  ,
#         601.25,  601.5 ,  601.75,  602.  ,  602.25,  602.5 ,  602.75,
#         603.  ,  603.25,  603.5 ,  603.75,  604.  ,  604.25,  604.5 ,
#         604.75,  605.  ,  605.25,  605.5 ,  605.75,  606.  ,  606.25,
#         606.5 ,  606.75,  607.  ,  607.25,  607.5 ,  607.75,  608.  ,
#         608.25,  608.5 ,  608.75,  609.  ,  609.25,  609.5 ,  609.75,
#         610.  ,  610.25,  610.5 ,  610.75,  611.  ,  611.25,  611.5 ,
#         611.75,  612.  ,  612.25,  612.5 ,  612.75,  613.  ,  613.25,
#         613.5 ,  613.75,  614.  ,  614.25,  614.5 ,  614.75,  615.  ,
#         615.25,  615.5 ,  615.75,  616.  ,  616.25,  616.5 ,  616.75,
#         617.  ,  617.25,  617.5 ,  617.75,  618.  ,  618.25,  618.5 ,
#         618.75,  619.  ,  619.25,  619.5 ,  619.75,  620.  ,  620.25,
#         620.5 ,  620.75,  621.  ,  621.25,  621.5 ,  621.75,  622.  ,
#         622.25,  622.5 ,  622.75,  623.  ,  623.25,  623.5 ,  623.75,
#         624.  ,  624.25,  624.5 ,  624.75,  625.  ,  625.25,  625.5 ,
#         625.75,  626.  ,  626.25,  626.5 ,  626.75,  627.  ,  627.25,
#         627.5 ,  627.75,  628.  ,  628.25,  628.5 ,  628.75,  629.  ,
#         629.25,  629.5 ,  629.75,  630.  ,  630.25,  630.5 ,  630.75,
#         631.  ,  631.25,  631.5 ,  631.75,  632.  ,  632.25,  632.5 ,
#         632.75,  633.  ,  633.25,  633.5 ,  633.75,  634.  ,  634.25,
#         634.5 ,  634.75,  635.  ,  635.25,  635.5 ,  635.75,  636.  ,
#         636.25,  636.5 ,  636.75,  637.  ,  637.25,  637.5 ,  637.75,
#         638.  ,  638.25,  638.5 ,  638.75,  639.  ,  639.25,  639.5 ,
#         639.75,  640.  ])

# %%
from welly import Project

# %%
p = Project.from_las('Logs/*.LAS')
# Out:
# 0it [00:00, ?it/s]

# %%
p
# Out:
# Project()

# %%
keys = ['ILD','DPHI','GR','NPHI','CALI','COND','DELT','RHOB','PHIN','DT','ILM','SP','SFLU','IL','DEPTH','DEPH','MD']

# %%
keys2 = ['ILD','DPHI','GR','NPHI','CALI','RHOB']

# %%
html = p[1200:2000].curve_table_html(keys=keys)

# %%
from IPython.display import HTML
HTML(html)
# Out:
# <table><tr><th>Idx</th><th>UWI</th><th>Data</th><th>Quality</th><th>ILD</th><th>DPHI</th><th>GR</th><th>NPHI</th><th>CALI</th><th>COND</th><th>DELT</th><th>RHOB</th><th>PHIN</th><th>DT</th><th>ILM</th><th>SP</th><th>SFLU</th><th>IL</th><th>DEPTH</th><th>DEPH</th><th>MD</th></tr><tr><td></td><td></td><td></td><td>%</td><td>0/0&nbsp;wells</td><td>0/0&nbsp;wells</td><td>0/0&nbsp;wells</td><td>0/0&nbsp;wells</td><td>0/0&nbsp;wells</td><td>0/0&nbsp;wells</td><td>0/0&nbsp;wells</td><td>0/0&nbsp;wells</td><td>0/0&nbsp;wells</td><td>0/0&nbsp;wells</td><td>0/0&nbsp;wells</td><td>0/0&nbsp;wells</td><td>0/0&nbsp;wells</td><td>0/0&nbsp;wells</td><td>0/0&nbsp;wells</td><td>0/0&nbsp;wells</td><td>0/0&nbsp;wells</td></tr></table>
